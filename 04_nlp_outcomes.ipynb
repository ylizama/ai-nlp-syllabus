# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

import re
import os
import string
import operator
from itertools import islice
from collections import Counter

from datetime import date
import matplotlib.dates as dates

from nltk import ngrams
import nltk as nltk
from nltk.corpus import stopwords

# %%
sns.set_style('darkgrid')
sns.set_context('paper')
pd.set_option('display.max_colwidth', None)

# %%
punct_signs = list(string.punctuation)
punct_signs.append('…')
punct_signs.append('¿')
punct_signs.append('•')
punct_signs.append('”')
punct_signs.append('“')
punct_signs.append('–')
punct_signs.remove('&')
punct_signs.append('∑')

stop_words = stopwords.words('english') + ['also', 'could', ]

# %%
df = pd.read_csv('data/courses.csv')
df = df.fillna("")
df.columns
# Out:
# Index(['ID', 'Country', 'Univeristy', 'G2RWorldRank', 'G2RNationalRank',
#        'QSWorldUniversityRanking2021', 'Program',
#        'SchoolOfferingCourseProgram', 'CourseDescription', 'Course Unit',
#        'CourseUnitGoals', 'CourseUnitOutcomes'],
#       dtype='object')

# %%
import math
def clean_text(text):
    for p in punct_signs:
        text = text.replace(p, ' ')
    clean_text = text.lower().split()
    clean_text = [w for w in clean_text if w not in stop_words]
    return clean_text

# %% [markdown]
# ## 50 most frequently used ngrams in description

# %%
#m is the number of top ngrams.
def getNGrams(text, n, m):
    h_dict = {}   
    ngramas = list(ngrams(text, n))
    for grams in ngramas:
        words = ' '.join(grams).strip()
        if words not in h_dict:
            h_dict[words] = 0
        h_dict[words] = h_dict[words] + 1
        
    sorted_dict = sorted(h_dict.items(), key=operator.itemgetter(1), reverse=True)
    top_values = list(islice(sorted_dict, m))
    return [(r[0], r[1], round(r[1]/len(ngramas)*100,2)) for r in top_values]

def printNgrams(data, m):
    Ngrams = []
    unigrams = getNGrams(data, 1, m)
    bigrams = getNGrams(data, 2 , m)
    trigrams = getNGrams(data, 3 , m)
    for i in range(0,m):
        Ngrams.append(unigrams[i] + bigrams[i] + trigrams[i])
    df = pd.DataFrame(Ngrams, columns=['Unigrams', 'Absolute Freq', 'Relative Freq', 
                                       'Bigrams', 'Absolute Freq', 'Relative Freq', 
                                       'Trigrams', 'Absolute Freq', 'Relative Freq',]) 
    return df

# %%
data = ' '.join(list(df['CourseUnitOutcomes']))
data  = clean_text(data)

# %%
dfNgrams = printNgrams(data, 50)
dfNgrams
# Out:
#          Unigrams  Absolute Freq  Relative Freq  \
# 0            data             99           2.10
# 1     engineering             66           1.40
# 2      understand             59           1.25
# 3          design             53           1.12
# 4        research             48           1.02
# 5         science             46           0.98
# 6         ability             44           0.93
# 7           apply             43           0.91
# 8         ethical             41           0.87
# 9        evaluate             39           0.83
# 10       identify             38           0.81
# 11    appropriate             37           0.78
# 12           able             37           0.78
# 13     healthcare             36           0.76
# 14      knowledge             35           0.74
# 15       students             35           0.74
# 16            use             34           0.72
# 17       computer             33           0.70
# 18       describe             33           0.70
# 19             ai             31           0.66
# 20       learning             29           0.61
# 21         social             28           0.59
# 22       problems             27           0.57
# 23     techniques             27           0.57
# 24         global             26           0.55
# 25      solutions             25           0.53
# 26           well             24           0.51
# 27  environmental             23           0.49
# 28    effectively             23           0.49
# 29       societal             23           0.49
# 30        machine             23           0.49
# 31         system             22           0.47
# 32        systems             22           0.47
# 33        related             22           0.47
# 34     innovation             22           0.47
# 35           meet             21           0.45
# 36       approach             21           0.45
# 37        develop             20           0.42
# 38     technology             20           0.42
# 39      formulate             19           0.40
# 40   professional             19           0.40
# 41     challenges             19           0.40
# 42    demonstrate             19           0.40
# 43  understanding             19           0.40
# 44          using             18           0.38
# 45         skills             18           0.38
# 46        project             17           0.36
# 47         within             17           0.36
# 48       economic             16           0.34
# 49    communicate             16           0.34
#
#                           Bigrams  Absolute Freq  Relative Freq  \
# 0                computer science             19           0.40
# 1                machine learning             18           0.38
# 2                 healthcare data             18           0.38
# 3                   health safety             13           0.28
# 4                solutions global             13           0.28
# 5              identify formulate             12           0.25
# 6                 formulate solve             12           0.25
# 7         communicate effectively             11           0.23
# 8             demonstrate ability             11           0.23
# 9            engineering problems             10           0.21
# 10           students demonstrate             10           0.21
# 11         economic environmental              9           0.19
# 12               system component              8           0.17
# 13                   meet desired              8           0.17
# 14                  desired needs              8           0.17
# 15              understand impact              8           0.17
# 16                global societal              8           0.17
# 17               societal context              8           0.17
# 18               related computer              8           0.17
# 19               data engineering              8           0.17
# 20          engineering solutions              7           0.15
# 21           function effectively              7           0.15
# 22              analyze interpret              7           0.15
# 23        artificial intelligence              7           0.15
# 24                  students able              7           0.15
# 25                            e g              7           0.15
# 26                  ability apply              6           0.13
# 27              apply engineering              6           0.13
# 28             engineering design              6           0.13
# 29                 design produce              6           0.13
# 30              produce solutions              6           0.13
# 31                 solutions meet              6           0.13
# 32                 meet specified              6           0.13
# 33                specified needs              6           0.13
# 34            needs consideration              6           0.13
# 35           consideration public              6           0.13
# 36                  public health              6           0.13
# 37                 safety welfare              6           0.13
# 38                   welfare well              6           0.13
# 39                global cultural              6           0.13
# 40                cultural social              6           0.13
# 41           social environmental              6           0.13
# 42         environmental economic              6           0.13
# 43               economic factors              6           0.13
# 44  professional responsibilities              6           0.13
# 45                  make informed              6           0.13
# 46             impact engineering              6           0.13
# 47               ability function              6           0.13
# 48               effectively team              6           0.13
# 49                     team whose              6           0.13
#
#                            Trigrams  Absolute Freq  Relative Freq
# 0          identify formulate solve             12           0.25
# 1                meet desired needs              8           0.17
# 2         solutions global societal              8           0.17
# 3           global societal context              8           0.17
# 4      engineering solutions global              7           0.15
# 5      students demonstrate ability              7           0.15
# 6         ability apply engineering              6           0.13
# 7          apply engineering design              6           0.13
# 8        engineering design produce              6           0.13
# 9          design produce solutions              6           0.13
# 10           produce solutions meet              6           0.13
# 11         solutions meet specified              6           0.13
# 12             meet specified needs              6           0.13
# 13    specified needs consideration              6           0.13
# 14       needs consideration public              6           0.13
# 15      consideration public health              6           0.13
# 16             public health safety              6           0.13
# 17            health safety welfare              6           0.13
# 18              safety welfare well              6           0.13
# 19           global cultural social              6           0.13
# 20    cultural social environmental              6           0.13
# 21    social environmental economic              6           0.13
# 22   environmental economic factors              6           0.13
# 23     impact engineering solutions              6           0.13
# 24     ability function effectively              6           0.13
# 25        function effectively team              6           0.13
# 26           effectively team whose              6           0.13
# 27               team whose members              6           0.13
# 28           whose members together              6           0.13
# 29         members together provide              6           0.13
# 30      together provide leadership              6           0.13
# 31        provide leadership create              6           0.13
# 32  leadership create collaborative              6           0.13
# 33      environment establish goals              6           0.13
# 34             establish goals plan              6           0.13
# 35                 goals plan tasks              6           0.13
# 36                  plan tasks meet              6           0.13
# 37            tasks meet objectives              6           0.13
# 38         related computer science              6           0.13
# 39             understand role data              6           0.13
# 40    value propositions understand              6           0.13
# 41       ability identify formulate              5           0.11
# 42          formulate solve complex              5           0.11
# 43        solve complex engineering              5           0.11
# 44     complex engineering problems              5           0.11
# 45    engineering problems applying              5           0.11
# 46     problems applying principles              5           0.11
# 47  applying principles engineering              5           0.11
# 48   principles engineering science              5           0.11
# 49  engineering science mathematics              5           0.11

# %% [markdown]
# ## 30 Most used verbs and adjectives in description

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
nltk.download('wordnet');
# Out:
# [nltk_data] Downloading package punkt to /home/yadira/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/yadira/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/yadira/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#m is the number of top ngrams.
def getNPartsOfSpeech(text, m, tag):
    h_dict = {}   
    tokens = nltk.word_tokenize(text)
    pos_tags = nltk.pos_tag(tokens)
    #lemmatization and filtering allowed tags
    filtered_tags = [wordnet_lemmatizer.lemmatize(pt[0], pos="v") for pt in pos_tags if pt[1].startswith(tag)]
    
    for ft in filtered_tags:    
        if ft not in h_dict:
            h_dict[ft] = 0
        h_dict[ft] += 1
        
    sorted_dict = sorted(h_dict.items(), key=operator.itemgetter(1), reverse=True)
    top_values = list(islice(sorted_dict, m))
    return [(r[0], r[1], round(r[1]/len(filtered_tags)*100,2)) for r in top_values]

def printNPOS(data, m):
    postags = []
    
    verbs = getNPartsOfSpeech(data, m, 'V')
    verbs += [(None, None)] * (m - len(verbs))
    
    adjs = getNPartsOfSpeech(data, m , 'J')
    adjs +=[(None, None)] * (m - len(adjs))
    
    nouns = getNPartsOfSpeech(data, m , 'N')
    nouns +=[(None, None)] * (m - len(nouns))
    
    for i in range(0,m):
        if all(verbs[i]) or all(adj[i]) or all(nouns[i]):
            postags.append(verbs[i] + adjs[i] + nouns[i])
    df = pd.DataFrame(postags, columns=['Verbs', 'Absolute Freq', 'Relative Freq', 
                                       'Adjectives', 'Absolute Freq', 'Relative Freq',
                                        'Nouns', 'Absolute Freq', 'Relative Freq' ]) 
    return df

# %%
data = ' '.join(list(df['CourseUnitOutcomes']))

# %%
printNPOS(data, 30)
# Out:
#           Verbs  Absolute Freq  Relative Freq       Adjectives  Absolute Freq  \
# 0            be             64           7.73          ethical             40
# 1         apply             36           4.35             able             34
# 2           use             31           3.74           social             27
# 3      identify             23           2.78           global             26
# 4        relate             21           2.54      appropriate             25
# 5          meet             20           2.42    environmental             23
# 6    understand             20           2.42         societal             22
# 7         solve             17           2.05     professional             19
# 8      evaluate             17           2.05         economic             15
# 9   demonstrate             17           2.05         critical             13
# 10      include             16           1.93             such             13
# 11     consider             12           1.45         specific             12
# 12  communicate             11           1.33        different             12
# 13       create             11           1.33            other             12
# 14      develop             11           1.33          current             12
# 15      produce             10           1.21            basic             11
# 16         make             10           1.21      fundamental             10
# 17      provide             10           1.21                /             10
# 18      conduct              9           1.09        necessary             10
# 19    formulate              8           0.97          complex              9
# 20     function              7           0.85        practical              9
# 21    establish              7           0.85         relevant              9
# 22      acquire              7           0.85          various              9
# 23         need              7           0.85  entrepreneurial              9
# 24      address              7           0.85             main              8
# 25        learn              7           0.85      statistical              8
# 26         work              7           0.85           desire              8
# 27         draw              6           0.72       artificial              8
# 28      explain              6           0.72            legal              8
# 29      analyze              6           0.72           public              7
#
#     Relative Freq       Nouns  Absolute Freq  Relative Freq
# 0            4.07        data             70           2.73
# 1            3.46    engineer             65           2.54
# 2            2.75    research             47           1.83
# 3            2.64     ability             44           1.72
# 4            2.54     science             43           1.68
# 5            2.34   knowledge             34           1.33
# 6            2.24      design             33           1.29
# 7            1.93    computer             33           1.29
# 8            1.53    approach             28           1.09
# 9            1.32  healthcare             27           1.05
# 10           1.32   solutions             23           0.90
# 11           1.22  techniques             23           0.90
# 12           1.22          AI             23           0.90
# 13           1.22     machine             22           0.86
# 14           1.22         use             22           0.86
# 15           1.12  innovation             22           0.86
# 16           1.02  understand             21           0.82
# 17           1.02    problems             19           0.74
# 18           1.02      system             19           0.74
# 19           0.92      impact             18           0.70
# 20           0.92        team             18           0.70
# 21           0.92   challenge             18           0.70
# 22           0.92     systems             18           0.70
# 23           0.92       learn             17           0.66
# 24           0.81      skills             17           0.66
# 25           0.81  technology             16           0.62
# 26           0.81  principles             14           0.55
# 27           0.81      safety             14           0.55
# 28           0.81     project             14           0.55
# 29           0.71     methods             14           0.55
